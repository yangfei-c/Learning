# %% [markdown]
# # 调试

# %% [markdown]
# ## 取得反向追踪字符串

# %%
def spam():
    bacon()
def bacon():
    raise Exception('The is  the error message')
spam()
# Out:
# ---------------------------------------------------------------------------
# Exception                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_8220\777566239.py in <module>
#       3 def bacon():
#       4     raise Exception('The is  the error message')
# ----> 5 spam()
#
# ~\AppData\Local\Temp\ipykernel_8220\777566239.py in spam()
#       1 def spam():
# ----> 2     bacon()
#       3 def bacon():
#       4     raise Exception('The is  the error message')
#       5 spam()
#
# ~\AppData\Local\Temp\ipykernel_8220\777566239.py in bacon()
#       2     bacon()
#       3 def bacon():
# ----> 4     raise Exception('The is  the error message')
#       5 spam()
#
# Exception: The is  the error message

# %%
import traceback
try:
    raise Exception('This is the error message')
except:
    error_file=open('error_info.txt','w')
    error_file.write(traceback.format_exc())
    error_file.close()
    print('the traceback info was written to error_info.txt')
# Out:
# the traceback info was written to error_info.txt
