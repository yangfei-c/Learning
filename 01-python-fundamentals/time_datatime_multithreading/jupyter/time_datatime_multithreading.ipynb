# %% [markdown]
# # time

# %%
import time
t=time.time()

# %%
start_time=time.time()
print('djd')
end_time=time.time()
over_time=start_time-end_time
over_time
# Out:
# djd
# 0.0

# %%
for i in range(4):
    print('main')
    time.sleep(3)
# Out:
# main
# main
# main
# main
